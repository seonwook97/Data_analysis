# %% [markdown]
# # 문제 (1)
#
# - 어떤 경로든 covid-19의 데이터를 얻으세요. 가급적 2020년 1~2월부터 최소 600일 이상의 데이터면 좋겠습니다.

# %%
import pandas as pd
import numpy as np
import datetime
import warnings

warnings.filterwarnings(action='ignore')

# %%
# 국가별 일별 누적 확진자 수 데이터 불러오기
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
confirmed_df.head(3)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  10/7/21  10/8/21  10/9/21  \
# 0        0        0        0        0  ...   155429   155448   155466
# 1        0        0        0        0  ...   173723   174168   174643
# 2        0        0        0        0  ...   204276   204388   204490
#
#    10/10/21  10/11/21  10/12/21  10/13/21  10/14/21  10/15/21  10/16/21
# 0    155508    155540    155599    155627    155682    155688    155739
# 1    174968    175163    175664    176172    176667    177108    177536
# 2    204597    204695    204790    204900    205005    205106    205199
#
# [3 rows x 638 columns]

# %%
# 국가별 일별 누적 사망자 수 데이터 불러오기
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
deaths_df.head(3)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  10/7/21  10/8/21  10/9/21  \
# 0        0        0        0        0  ...     7221     7221     7221
# 1        0        0        0        0  ...     2746     2753     2759
# 2        0        0        0        0  ...     5843     5846     5850
#
#    10/10/21  10/11/21  10/12/21  10/13/21  10/14/21  10/15/21  10/16/21
# 0      7225      7228      7230      7234      7238      7238      7238
# 1      2768      2777      2783      2788      2797      2807      2810
# 2      5853      5855      5859      5862      5864      5867      5870
#
# [3 rows x 638 columns]

# %% [markdown]
# ---

# %% [markdown]
# # 문제 (2)
#
# - 우리는 전세계의 데이터를 사용하지 않을려고 합니다. 애초 목적에 비춰 우리와 비슷한 수준 혹은 이 이상의 경제력을 가진 나라들을 가지고 다시 데이터를 구성해야하는 것이 타당해보입니다.
#
# - 예를 들어 누구나 선진국으로 인정하는 미국, 영국, 프랑스, 이탈리아, 이스라엘, 일본 등등의 나라가 될 것입니다. 어쩌면 여러분들은 G20 국가를 선택해도 되지 않을까 합니다. 단 자신들의 확진자수를 공개하고 있는 나라 중에서 선택하면 될 것 입니다.
#
# - 여러분들이 직접 우리나라와 비교할 4개 국가를 선택해주세요. (단 중국은 여러 이슈가 있어서 데이터 수집에서 제외해 주세요)
#
# - 그래서 우리나라와 선택된 4개국가, 합쳐서 5개의 국가를 앞으로는“전체데이터”라고 하겠습니다.

# %%
# 국가별 일별 누적 확진자 수 데이터 불러오기
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
confirmed_df.head(3)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  10/7/21  10/8/21  10/9/21  \
# 0        0        0        0        0  ...   155429   155448   155466
# 1        0        0        0        0  ...   173723   174168   174643
# 2        0        0        0        0  ...   204276   204388   204490
#
#    10/10/21  10/11/21  10/12/21  10/13/21  10/14/21  10/15/21  10/16/21
# 0    155508    155540    155599    155627    155682    155688    155739
# 1    174968    175163    175664    176172    176667    177108    177536
# 2    204597    204695    204790    204900    205005    205106    205199
#
# [3 rows x 638 columns]

# %%
# 5개 국가별 일별 누적 확진자 수 데이터 프레임 생성

# 한국 누적 확진자 수
confirmed_SouthKorea = confirmed_df[confirmed_df['Country/Region'] == 'Korea, South']
confirmed_SouthKorea

# 일본 누적 확진자 수
confirmed_Japan = confirmed_df[confirmed_df['Country/Region'] == 'Japan']
confirmed_Japan

# 미국 누적 확진자 수
confirmed_US = confirmed_df[confirmed_df['Country/Region'] == 'US']
confirmed_US

# 영국 누적 확진자 수
confirmed_UK = confirmed_df[confirmed_df['Country/Region'] == 'United Kingdom']
confirmed_UK = pd.DataFrame(confirmed_UK.iloc[11,:])
confirmed_UK = confirmed_UK.transpose()
confirmed_UK

# 독일 누적 확진자 수
confirmed_Germany = confirmed_df[confirmed_df['Country/Region'] == 'Germany']
confirmed_Germany
# Out:
#     Province/State Country/Region        Lat       Long  1/22/20  1/23/20  \
# 134            NaN        Germany  51.165691  10.451526        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  10/7/21  10/8/21  10/9/21  \
# 134        0        0        0        1  ...  4295876  4305634  4312528
#
#      10/10/21  10/11/21  10/12/21  10/13/21  10/14/21  10/15/21  10/16/21
# 134   4318437   4323346   4331274   4343591   4355169   4366833   4375253
#
# [1 rows x 638 columns]

# %%
# 5개 국가별 df 합치기 -> 전체 일별 누적 확진자 수 데이터 프레임 생성
country_confirmed = pd.concat([confirmed_SouthKorea, confirmed_Japan, confirmed_US, confirmed_UK,confirmed_Germany], axis=0)
country_confirmed.set_index('Country/Region', inplace=True)
del country_confirmed['Province/State']
country_confirmed
# Out:
#                       Lat        Long 1/22/20 1/23/20 1/24/20 1/25/20 1/26/20  \
# Country/Region
# Korea, South    35.907757  127.766922       1       1       2       2       3
# Japan           36.204824  138.252924       2       2       2       2       4
# US                   40.0      -100.0       1       1       2       2       5
# United Kingdom    55.3781      -3.436       0       0       0       0       0
# Germany         51.165691   10.451526       0       0       0       0       0
#
#                1/27/20 1/28/20 1/29/20  ...   10/7/21   10/8/21   10/9/21  \
# Country/Region                          ...
# Korea, South         4       4       4  ...    327976    329925    331519
# Japan                4       7       7  ...   1709603   1710426   1711207
# US                   5       5       6  ...  44158910  44290052  44317989
# United Kingdom       0       0       0  ...   8046390   8081300   8120713
# ...

# %%
# 전체 위도, 경도 따로 df 만들어놓기
country_loc = country_confirmed[['Lat', 'Long']]
country_loc
# Out:
#                       Lat        Long
# Country/Region
# Korea, South    35.907757  127.766922
# Japan           36.204824  138.252924
# US                   40.0      -100.0
# United Kingdom    55.3781      -3.436
# Germany         51.165691   10.451526

# %%
# 위도, 경도 column 삭제
del country_confirmed['Lat']
del country_confirmed['Long']

# %%
# 전체 일별 누적 확진자 수
country_confirmed
# Out:
#                1/22/20 1/23/20 1/24/20 1/25/20 1/26/20 1/27/20 1/28/20  \
# Country/Region
# Korea, South         1       1       2       2       3       4       4
# Japan                2       2       2       2       4       4       7
# US                   1       1       2       2       5       5       5
# United Kingdom       0       0       0       0       0       0       0
# Germany              0       0       0       0       0       1       4
#
#                1/29/20 1/30/20 1/31/20  ...   10/7/21   10/8/21   10/9/21  \
# Country/Region                          ...
# Korea, South         4       4      11  ...    327976    329925    331519
# Japan                7      11      15  ...   1709603   1710426   1711207
# US                   6       6       8  ...  44158910  44290052  44317989
# United Kingdom       0       0       2  ...   8046390   8081300   8120713
# Germany              4       4       5  ...   4295876   4305634   4312528
#
# ...

# %%
# 국가별 일별 누적 사망자 수 데이터 불러오기
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
deaths_df.head(3)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  10/7/21  10/8/21  10/9/21  \
# 0        0        0        0        0  ...     7221     7221     7221
# 1        0        0        0        0  ...     2746     2753     2759
# 2        0        0        0        0  ...     5843     5846     5850
#
#    10/10/21  10/11/21  10/12/21  10/13/21  10/14/21  10/15/21  10/16/21
# 0      7225      7228      7230      7234      7238      7238      7238
# 1      2768      2777      2783      2788      2797      2807      2810
# 2      5853      5855      5859      5862      5864      5867      5870
#
# [3 rows x 638 columns]

# %%
# 5개 국가별 일별 누적 사망자 수 데이터 프레임 생성

# 한국 누적 사망자 수
deaths_SouthKorea = deaths_df[deaths_df['Country/Region'] == 'Korea, South']
deaths_SouthKorea

# 일본 누적 사망자 수
deaths_Japan = deaths_df[deaths_df['Country/Region'] == 'Japan']
deaths_Japan

# 미국 누적 사망자 수
deaths_US = deaths_df[deaths_df['Country/Region'] == 'US']
deaths_US

# 영국 누적 사망자 수
deaths_UK = deaths_df[deaths_df['Country/Region'] == 'United Kingdom']
deaths_UK = pd.DataFrame(deaths_UK.iloc[11,:])
deaths_UK = deaths_UK.transpose()
deaths_UK

# 독일 누적 사망자 수
deaths_Germany = deaths_df[deaths_df['Country/Region'] == 'Germany']
deaths_Germany
# Out:
#     Province/State Country/Region        Lat       Long  1/22/20  1/23/20  \
# 134            NaN        Germany  51.165691  10.451526        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  10/7/21  10/8/21  10/9/21  \
# 134        0        0        0        0  ...    94117    94182    94206
#
#      10/10/21  10/11/21  10/12/21  10/13/21  10/14/21  10/15/21  10/16/21
# 134     94213     94308     94393     94407     94530     94605     94622
#
# [1 rows x 638 columns]

# %%
# 5개 국가별 df 합치기 -> 전체 일별 누적 사망자 수 데이터 프레임 생성
country_deaths = pd.concat([deaths_SouthKorea, deaths_Japan, deaths_US, deaths_UK,deaths_Germany], axis=0)
country_deaths.set_index('Country/Region', inplace=True)
del country_deaths['Province/State']
del country_deaths['Lat']
del country_deaths['Long']
country_deaths
# Out:
#                1/22/20 1/23/20 1/24/20 1/25/20 1/26/20 1/27/20 1/28/20  \
# Country/Region
# Korea, South         0       0       0       0       0       0       0
# Japan                0       0       0       0       0       0       0
# US                   0       0       0       0       0       0       0
# United Kingdom       0       0       0       0       0       0       0
# Germany              0       0       0       0       0       0       0
#
#                1/29/20 1/30/20 1/31/20  ... 10/7/21 10/8/21 10/9/21 10/10/21  \
# Country/Region                          ...
# Korea, South         0       0       0  ...    2554    2560    2575     2583
# Japan                0       0       0  ...   17872   17918   17945    17952
# US                   0       0       0  ...  710502  712339  712618   712873
# United Kingdom       0       0       0  ...  137417  137541  137697   137735
# Germany              0       0       0  ...   94117   94182   94206    94213
#
# ...

# %%
# 인덱스인 국가명들을 한국어로 변경
country_confirmed = country_confirmed.rename(index={'Korea, South': '한국', 'Japan': '일본', 'US': '미국', 'United Kingdom': '영국', 'Germany': '독일'})
country_confirmed
# Out:
#                1/22/20 1/23/20 1/24/20 1/25/20 1/26/20 1/27/20 1/28/20  \
# Country/Region
# 한국                   1       1       2       2       3       4       4
# 일본                   2       2       2       2       4       4       7
# 미국                   1       1       2       2       5       5       5
# 영국                   0       0       0       0       0       0       0
# 독일                   0       0       0       0       0       1       4
#
#                1/29/20 1/30/20 1/31/20  ...   10/7/21   10/8/21   10/9/21  \
# Country/Region                          ...
# 한국                   4       4      11  ...    327976    329925    331519
# 일본                   7      11      15  ...   1709603   1710426   1711207
# 미국                   6       6       8  ...  44158910  44290052  44317989
# 영국                   0       0       2  ...   8046390   8081300   8120713
# 독일                   4       4       5  ...   4295876   4305634   4312528
#
# ...

# %%
# 인덱스인 국가명들을 한국어로 변경
country_deaths = country_deaths.rename(index={'Korea, South': '한국', 'Japan': '일본', 'US': '미국', 'United Kingdom': '영국', 'Germany': '독일'})
country_deaths
# Out:
#                1/22/20 1/23/20 1/24/20 1/25/20 1/26/20 1/27/20 1/28/20  \
# Country/Region
# 한국                   0       0       0       0       0       0       0
# 일본                   0       0       0       0       0       0       0
# 미국                   0       0       0       0       0       0       0
# 영국                   0       0       0       0       0       0       0
# 독일                   0       0       0       0       0       0       0
#
#                1/29/20 1/30/20 1/31/20  ... 10/7/21 10/8/21 10/9/21 10/10/21  \
# Country/Region                          ...
# 한국                   0       0       0  ...    2554    2560    2575     2583
# 일본                   0       0       0  ...   17872   17918   17945    17952
# 미국                   0       0       0  ...  710502  712339  712618   712873
# 영국                   0       0       0  ...  137417  137541  137697   137735
# 독일                   0       0       0  ...   94117   94182   94206    94213
#
# ...

# %%
# 인덱스인 국가명들을 한국어로 변경
country_loc = country_loc.rename(index={'Korea, South': '한국', 'Japan': '일본', 'US': '미국', 'United Kingdom': '영국', 'Germany': '독일'})
country_loc
# Out:
#                       Lat        Long
# Country/Region
# 한국              35.907757  127.766922
# 일본              36.204824  138.252924
# 미국                   40.0      -100.0
# 영국                55.3781      -3.436
# 독일              51.165691   10.451526

# %% [markdown]
# ---

# %% [markdown]
# # 문제 (3)
#
# - 이제 전체 데이터의 단순 시간대별 확진자수,사망자수 등을시각화하고
#
# - 구성된 5개 국가들을 개별적으로 동일하게 확진자수와 사망자수를 시각화 해주세요.
#
# - 여러분들 판단에 우리나라의 방역 대응 능력을 평가할 수있는 시각화 방법을 고민하고 제시해주세요.
#
# - 이번 문제는 하나의 그림으로 끝나지 않을 수도 있습니다.

# %%
cols = country_confirmed.keys()
cols
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '10/7/21', '10/8/21', '10/9/21', '10/10/21', '10/11/21', '10/12/21',
#        '10/13/21', '10/14/21', '10/15/21', '10/16/21'],
#       dtype='object', length=634)

# %%
dates = country_confirmed.keys()
world_cases = []
total_deaths = [] 
mortality_rate = []

for i in dates:
    confirmed_sum = country_confirmed[i].sum()
    death_sum = country_deaths[i].sum()    
    
    world_cases.append(confirmed_sum)
    total_deaths.append(death_sum)
    
    mortality_rate.append(death_sum/confirmed_sum)

# %%
def daily_increase(data):
    d = [] 
    for i in range(len(data)):
        if i == 0:
            d.append(data[0])
        else:
            d.append(data[i]-data[i-1])
    return d 

def moving_average(data, window_size):
    moving_average = []
    for i in range(len(data)):
        if i + window_size < len(data):
            moving_average.append(np.mean(data[i:i+window_size]))
        else:
            moving_average.append(np.mean(data[i:len(data)]))
    return moving_average

# window size
window = 7

# confirmed cases
world_daily_increase = daily_increase(world_cases)
world_confirmed_avg= moving_average(world_cases, window)
world_daily_increase_avg = moving_average(world_daily_increase, window)

# deaths
world_daily_death = daily_increase(total_deaths)
world_death_avg = moving_average(total_deaths, window)
world_daily_death_avg = moving_average(world_daily_death, window)

# %%
days_since_1_22 = np.array([i for i in range(len(dates))]).reshape(-1, 1)
world_cases = np.array(world_cases).reshape(-1, 1)
total_deaths = np.array(total_deaths).reshape(-1, 1)

# %%
days_in_future = 10
future_forcast = np.array([i for i in range(len(dates)+days_in_future)]).reshape(-1, 1)
adjusted_dates = future_forcast[:-10]

# %%
start = '1/22/2020'
start_date = datetime.datetime.strptime(start, '%m/%d/%Y')
future_forcast_dates = []
for i in range(len(future_forcast)):
    future_forcast_dates.append((start_date + datetime.timedelta(days=i)).strftime('%m/%d/%Y'))

# %%
import matplotlib.pyplot as plt

# %%
import set_matplotlib_hangul
# Out:
# Hangul OK in your Windows !!!

# %%
adjusted_dates = adjusted_dates.reshape(1, -1)[0]
plt.figure(figsize=(16, 10))
plt.plot(adjusted_dates, world_cases)
plt.plot(adjusted_dates, world_confirmed_avg, linestyle='dashed', color='orange')
plt.title('일별 누적 코로나 확진자 수 (전체 5개국)', size=25)
plt.xlabel('2020년 1월 22일 부터', size=20)
plt.ylabel('확진자수 (단위: 천만)', size=20)
plt.legend(['일일 누적 확진자 수', '주 평균 누적 확진자 수'], prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(adjusted_dates, total_deaths)
plt.plot(adjusted_dates, world_death_avg, linestyle='dashed', color='orange')
plt.title('일별 누적 코로나 사망자 수 (전체 5개국)', size=25)
plt.xlabel('2020년 1월 22일 부터', size=20)
plt.ylabel('사망자수', size=20)
plt.legend(['일일 누적 사망자 수', '주 평균 누적 사망자 수'], prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.bar(adjusted_dates, world_daily_increase)
plt.plot(adjusted_dates, world_daily_increase_avg, color='orange', linestyle='dashed')
plt.title('일별 코로나 확진자 수 (전체 5개국)', size=25)
plt.xlabel('2020년 1월 22일 부터', size=20)
plt.ylabel('확진자수', size=20)
plt.legend(['주 평균 확진자 수', '일일 확진자 수'], prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

plt.figure(figsize=(16, 10))
plt.bar(adjusted_dates, world_daily_death)
plt.plot(adjusted_dates, world_daily_death_avg, color='orange', linestyle='dashed')
plt.title('일별 코로나 사망자 수 (전체 5개국)', size=25)
plt.xlabel('2020년 1월 22일 부터', size=20)
plt.ylabel('사망자수', size=20)
plt.legend(['주 평균 사망자 수', '일일 사망자 수'], prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %%
def country_plot(x, y1, y2, y3, country):
    confirmed_avg = moving_average(y1, window)
    confirmed_increase_avg = moving_average(y2, window)
    death_increase_avg = moving_average(y3, window)
    
    plt.figure(figsize=(16, 10))
    plt.plot(x, y1)
    plt.plot(x, confirmed_avg, color='red', linestyle='dashed')
    plt.legend(['{} 일일 누적 확진자 수'.format(country), '주 평균 누적 확진자 수'], prop={'size': 15})
    plt.title('{} 일별 누적 코로나 확진자 수'.format(country), size=25)
    plt.xlabel('2020년 1월 22일 부터', size=20)
    plt.ylabel('확진자수', size=20)
    plt.xticks(size=15)
    plt.yticks(size=15)
    plt.show()

    plt.figure(figsize=(16, 10))
    plt.bar(x, y2)
    plt.plot(x, confirmed_increase_avg, color='red', linestyle='dashed')
    plt.legend(['주 평균 확진자 수', '{} 일일 확진자 수'.format(country)], prop={'size': 15})
    plt.title('{} 일별 코로나 확진자 수'.format(country), size=25)
    plt.xlabel('2020년 1월 22일 부터', size=20)
    plt.ylabel('확진자수', size=20)
    plt.xticks(size=15)
    plt.yticks(size=15)
    plt.show()

    plt.figure(figsize=(16, 10))
    plt.bar(x, y3)
    plt.plot(x, death_increase_avg, color='red', linestyle='dashed')
    plt.legend(['주 평균 사망자 수', '{} 일일 사망자 수'.format(country)], prop={'size': 15})
    plt.title('{} 일별 코로나 사망자 수'.format(country), size=25)
    plt.xlabel('2020년 1월 22일 부터', size=20)
    plt.ylabel('사망자수', size=20)
    plt.xticks(size=15)
    plt.yticks(size=15)
    plt.show()
       
def get_country_info(country_name):
    country_cases = []
    country_deaths = []
      
    for i in dates:
        country_cases.append(confirmed_df[confirmed_df['Country/Region']==country_name][i].sum())
        country_deaths.append(deaths_df[deaths_df['Country/Region']==country_name][i].sum())
    return (country_cases, country_deaths)
    
    
def country_visualizations(country_name):
    country_info = get_country_info(country_name)
    country_cases = country_info[0]
    country_deaths = country_info[1]
    
    country_daily_increase = daily_increase(country_cases)
    country_daily_death = daily_increase(country_deaths)
    
    country_plot(adjusted_dates, country_cases, country_daily_increase, country_daily_death, country_name)

# %%
# 반복문에 적용시켜 선택한 5개 국가를 한국어로 시각화하기 위해 임시로 국가명을 한글로 바꿈 
confirmed_df.loc[(confirmed_df['Country/Region'] == 'Korea, South'), 'Country/Region'] = '한국'
deaths_df.loc[(deaths_df['Country/Region'] == 'Korea, South'), 'Country/Region'] = '한국'

confirmed_df.loc[(confirmed_df['Country/Region'] == 'Japan'), 'Country/Region'] = '일본'
deaths_df.loc[(deaths_df['Country/Region'] == 'Japan'), 'Country/Region'] = '일본'

confirmed_df.loc[(confirmed_df['Country/Region'] == 'US'), 'Country/Region'] = '미국'
deaths_df.loc[(deaths_df['Country/Region'] == 'US'), 'Country/Region'] = '미국'

confirmed_df.loc[(confirmed_df['Country/Region'] == 'United Kingdom'), 'Country/Region'] = '영국'
deaths_df.loc[(deaths_df['Country/Region'] == 'United Kingdom'), 'Country/Region'] = '영국'

confirmed_df.loc[(confirmed_df['Country/Region'] == 'Germany'), 'Country/Region'] = '독일'
deaths_df.loc[(deaths_df['Country/Region'] == 'Germany'), 'Country/Region'] = '독일'

# %%
countries = ['한국', '일본', '미국', '영국', '독일']

for country in countries:
    country_visualizations(country)

# %%
Korea_daily_increase = daily_increase(get_country_info('한국')[0])
Korea_daily_death = daily_increase(get_country_info('한국')[1])

Japan_daily_increase = daily_increase(get_country_info('일본')[0])
Japan_daily_death = daily_increase(get_country_info('일본')[1])

USA_daily_increase = daily_increase(get_country_info('미국')[0])
USA_daily_death = daily_increase(get_country_info('미국')[1])

UK_daily_increase = daily_increase(get_country_info('영국')[0])
UK_daily_death = daily_increase(get_country_info('영국')[1])

Ger_daily_increase = daily_increase(get_country_info('독일')[0])
Ger_daily_death = daily_increase(get_country_info('독일')[1])

# %%
Korea_daily_df = pd.DataFrame({'일일 확진자 수': Korea_daily_increase,
                               '일일 사망자 수': Korea_daily_death})

Japan_daily_df = pd.DataFrame({'일일 확진자 수': Japan_daily_increase,
                               '일일 사망자 수': Japan_daily_death})

USA_daily_df = pd.DataFrame({'일일 확진자 수': USA_daily_increase,
                               '일일 사망자 수': USA_daily_death})

UK_daily_df = pd.DataFrame({'일일 확진자 수': UK_daily_increase,
                               '일일 사망자 수': UK_daily_death})

Ger_daily_df = pd.DataFrame({'일일 확진자 수': Ger_daily_increase,
                               '일일 사망자 수': Ger_daily_death})

# %%
Korea_daily_df['일일 확진자 대비 사망자 비율'] = Korea_daily_df['일일 사망자 수'] / Korea_daily_df['일일 확진자 수'] * 100
Korea_daily_df.fillna(0, inplace=True)

Japan_daily_df['일일 확진자 대비 사망자 비율'] = Japan_daily_df['일일 사망자 수'] / Japan_daily_df['일일 확진자 수'] * 100
Japan_daily_df.fillna(0, inplace=True)

USA_daily_df['일일 확진자 대비 사망자 비율'] = USA_daily_df['일일 사망자 수'] / USA_daily_df['일일 확진자 수'] * 100
USA_daily_df.fillna(0, inplace=True)

UK_daily_df['일일 확진자 대비 사망자 비율'] = UK_daily_df['일일 사망자 수'] / UK_daily_df['일일 확진자 수'] * 100
UK_daily_df.fillna(0, inplace=True)

Ger_daily_df['일일 확진자 대비 사망자 비율'] = Ger_daily_df['일일 사망자 수'] / Ger_daily_df['일일 확진자 수'] * 100
Ger_daily_df.fillna(0, inplace=True)

# %%
avg_rate = [np.mean(Korea_daily_df['일일 확진자 대비 사망자 비율']), np.mean(Japan_daily_df['일일 확진자 대비 사망자 비율']), np.mean(USA_daily_df['일일 확진자 대비 사망자 비율']), np.mean(UK_daily_df['일일 확진자 대비 사망자 비율']), np.mean(Ger_daily_df['일일 확진자 대비 사망자 비율'])]
avg_death_rate_per_confirmed = pd.DataFrame({'국가':['한국', '일본', '미국', '영국', '독일'],
                                             '일일 확진자 대비 사망자 비율 평균': avg_rate})
avg_death_rate_per_confirmed.set_index('국가', inplace=True)
avg_death_rate_per_confirmed
avg_death_rate_per_confirmed.sort_values(by='일일 확진자 대비 사망자 비율 평균').plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 일별 확진자 대비 사망자 비율 평균 (%)',
    xlabel='국가',
    color='red',
)

# %% [markdown]
# - 독일의 값은 코딩과정에서 문제가 있었는지 수정을 해도 inf가 반환되어 일단 결과 해석에서는 잠시 제외하였다.
#
# - 우리나라의 방역 대응 능력을 평가할 수 있는 능력은 타 국가 대비 확진자 수 / 사망자 수의 비율로 판단하였다.
#
# - 630일의 데이터이므로 비율을 630일로 나누어 평균을 낸 일일 확진자 대비 사망자 비율의 평균으로 시각화를 하였다.
#
# - 독일을 제외한 선정한 나머지 3개 국가에 비해 우리나라의 비율 평균이 약 2%대로 가장 낮았기 때문에 미국, 일본, 영국보다는 방역 대응 능력이 뛰어나다고 판단하였다.

# %% [markdown]
# ---

# %% [markdown]
# # 문제 (4)
#
# - 문제3의 경우에서 다시 인구수별 비율로 표현하려는 노력도 함께 해주세요.
#
# - 5개 국가뿐이니 인구수는 단순 검색을 통해 용이하게 구할 수 있을 것으로 보입니다.

# %%
# 국가별 현재까지 누적 확진자, 사망자 df 생성
confirmed_pop_rate = pd.DataFrame({'현재 누적 사망자 수': country_deaths.iloc[0:5, 632],
                                   '현재 누적 확진자 수': country_confirmed.iloc[0:5, 632]})

# 컬럼 순서 변경
confirmed_pop_rate = confirmed_pop_rate[['현재 누적 확진자 수', '현재 누적 사망자 수']]

# 국가별 인구수 컬럼 추가
confirmed_pop_rate['인구수'] = [51611400, 125960000, 332915074, 67886011, 83783942 ]

# 인구 대비 누적 확진자, 사망자 컬럼 추가
confirmed_pop_rate['인구 대비 누적 확진자 비율'] = confirmed_pop_rate['현재 누적 확진자 수'] / confirmed_pop_rate['인구수'] * 100
confirmed_pop_rate['인구 대비 누적 사망자 비율'] = confirmed_pop_rate['현재 누적 사망자 수'] / confirmed_pop_rate['인구수'] * 100

confirmed_pop_rate
# Out:
#                현재 누적 확진자 수 현재 누적 사망자 수        인구수 인구 대비 누적 확진자 비율  \
# Country/Region
# 한국                  340978        2644   51611400        0.660664
# 일본                 1714201       18084  125960000        1.360909
# 미국                44884868      723754  332915074       13.482378
# 영국                 8361651      138379   67886011       12.317193
# 독일                 4366833       94605   83783942        5.212017
#
#                인구 대비 누적 사망자 비율
# Country/Region
# 한국                    0.005123
# 일본                    0.014357
# 미국                    0.217399
# 영국                     0.20384
# 독일                    0.112915

# %%
confirmed_pop_rate['인구 대비 누적 확진자 비율'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 인구 대비 코로나 누적 확진자 비율 (%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange'])

# %%
confirmed_pop_rate['인구 대비 누적 사망자 비율'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 인구 대비 코로나 누적 사망자 비율 (%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange'])

# %% [markdown]
# - 국가별 인구 대비 코로나 누적 확진자 비율은 미국이 약 13%로 가장 높았고, 한국이 약 0.6%로 가장 낮았다
# - 국가별 인구 대비 코로나 누적 사망자 비율 역시 미국이 약 0.2%로 가장 높았으며, 한국이 약 0.005%로 가장 낮았다

# %% [markdown]
# ---

# %% [markdown]
# # 문제 (5)
#
# - 전체 데이터의 시계열 분석을 통해 전체 트렌드와 주기별 특성을 관찰해 주세요. 어떤 특이점이 있나요?
# - 5개 각 국가의 데이터에서는 동일과정에서 어떤 특이한 현상이 있나요?

# %%
ds = pd.date_range('2020-01-22', periods=634, freq='D')

df_confirmed = pd.DataFrame({'ds':ds, 
                             '한국 누적 확진자 수': country_confirmed.loc['한국'],
                             '일본 누적 확진자 수': country_confirmed.loc['일본'],
                             '미국 누적 확진자 수': country_confirmed.loc['미국'],
                             '영국 누적 확진자 수': country_confirmed.loc['영국'],
                             '독일 누적 확진자 수': country_confirmed.loc['독일'],})

df_deaths = pd.DataFrame({'ds':ds, 
                          '한국 누적 사망자 수': country_deaths.loc['한국'],
                          '일본 누적 사망자 수': country_deaths.loc['일본'],
                          '미국 누적 사망자 수': country_deaths.loc['미국'],
                          '영국 누적 사망자 수': country_deaths.loc['영국'],
                          '독일 누적 사망자 수': country_deaths.loc['독일'],})

# %%
df_confirmed.reset_index(inplace=True)
del df_confirmed['index']
df_confirmed.head()
# Out:
#           ds 한국 누적 확진자 수 일본 누적 확진자 수 미국 누적 확진자 수 영국 누적 확진자 수 독일 누적 확진자 수
# 0 2020-01-22           1           2           1           0           0
# 1 2020-01-23           1           2           1           0           0
# 2 2020-01-24           2           2           2           0           0
# 3 2020-01-25           2           2           2           0           0
# 4 2020-01-26           3           4           5           0           0

# %%
df_confirmed.tail()
# Out:
#             ds 한국 누적 확진자 수 일본 누적 확진자 수 미국 누적 확진자 수 영국 누적 확진자 수 독일 누적 확진자 수
# 629 2021-10-12      335742     1712740    44562693     8231437     4331274
# 630 2021-10-13      337679     1713471    44684150     8272883     4343591
# 631 2021-10-14      339361     1714060    44767906     8317439     4355169
# 632 2021-10-15      340978     1714201    44884868     8361651     4366833
# 633 2021-10-16      342396     1715059    44916423     8404469     4375253

# %%
df_deaths.reset_index(inplace=True)
del df_deaths['index']
df_deaths.head()
# Out:
#           ds 한국 누적 사망자 수 일본 누적 사망자 수 미국 누적 사망자 수 영국 누적 사망자 수 독일 누적 사망자 수
# 0 2020-01-22           0           0           0           0           0
# 1 2020-01-23           0           0           0           0           0
# 2 2020-01-24           0           0           0           0           0
# 3 2020-01-25           0           0           0           0           0
# 4 2020-01-26           0           0           0           0           0

# %%
df_deaths.tail()
# Out:
#             ds 한국 누적 사망자 수 일본 누적 사망자 수 미국 누적 사망자 수 영국 누적 사망자 수 독일 누적 사망자 수
# 629 2021-10-12        2605       17999      716471      137944       94393
# 630 2021-10-13        2618       18032      719558      138080       94407
# 631 2021-10-14        2626       18063      721563      138237       94530
# 632 2021-10-15        2644       18084      723754      138379       94605
# 633 2021-10-16        2660       18099      724153      138527       94622

# %%
df_confirmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ds           634 non-null    datetime64[ns]
#  1   한국 누적 확진자 수  634 non-null    object
#  2   일본 누적 확진자 수  634 non-null    object
#  3   미국 누적 확진자 수  634 non-null    object
#  4   영국 누적 확진자 수  634 non-null    object
#  5   독일 누적 확진자 수  634 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 29.8+ KB

# %%
df_deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ds           634 non-null    datetime64[ns]
#  1   한국 누적 사망자 수  634 non-null    object
#  2   일본 누적 사망자 수  634 non-null    object
#  3   미국 누적 사망자 수  634 non-null    object
#  4   영국 누적 사망자 수  634 non-null    object
#  5   독일 누적 사망자 수  634 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 29.8+ KB

# %%
# 데이터형 변환 object => int
country = ['한국', '일본', '미국', '영국', '독일']

for a in country:
    df_confirmed[a + ' ' + '누적 확진자 수'] = df_confirmed[a + ' ' + '누적 확진자 수'].astype('int')
    df_deaths[a + ' ' + '누적 사망자 수'] = df_deaths[a + ' ' + '누적 사망자 수'].astype('int')

# %%
df_confirmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ds           634 non-null    datetime64[ns]
#  1   한국 누적 확진자 수  634 non-null    int32
#  2   일본 누적 확진자 수  634 non-null    int32
#  3   미국 누적 확진자 수  634 non-null    int32
#  4   영국 누적 확진자 수  634 non-null    int32
#  5   독일 누적 확진자 수  634 non-null    int32
# dtypes: datetime64[ns](1), int32(5)
# memory usage: 17.5 KB

# %%
df_deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ds           634 non-null    datetime64[ns]
#  1   한국 누적 사망자 수  634 non-null    int32
#  2   일본 누적 사망자 수  634 non-null    int32
#  3   미국 누적 사망자 수  634 non-null    int32
#  4   영국 누적 사망자 수  634 non-null    int32
#  5   독일 누적 사망자 수  634 non-null    int32
# dtypes: datetime64[ns](1), int32(5)
# memory usage: 17.5 KB

# %%
from fbprophet import Prophet

# %%
# 한국 누적 확진자 수 Forecast(90일)
subdf = df_confirmed[['ds', '한국 누적 확진자 수']].dropna()
subdf = subdf.rename(columns={'ds':'ds', '한국 누적 확진자 수':'y'})

m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(subdf);

future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)

m.plot(forecast);

# %%
m.plot_components(forecast);

# %%
# 일본 누적 확진자 수 Forecast(90일)
subdf = df_confirmed[['ds', '일본 누적 확진자 수']].dropna()
subdf = subdf.rename(columns={'ds':'ds', '일본 누적 확진자 수':'y'})

m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(subdf);

future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)

m.plot(forecast);

# %%
m.plot_components(forecast)

# %%
# 미국 누적 확진자 수 Forecast(90일)
subdf = df_confirmed[['ds', '미국 누적 확진자 수']].dropna()
subdf = subdf.rename(columns={'ds':'ds', '미국 누적 확진자 수':'y'})

m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(subdf);

future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)

m.plot(forecast);

# %%
m.plot_components(forecast)

# %%
# 영국 누적 확진자 수 Forecast(90일)
subdf = df_confirmed[['ds', '영국 누적 확진자 수']].dropna()
subdf = subdf.rename(columns={'ds':'ds', '영국 누적 확진자 수':'y'})

m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(subdf);

future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)

m.plot(forecast);

# %%
m.plot_components(forecast)

# %%
# 독일 누적 확진자 수 Forecast(90일)
subdf = df_confirmed[['ds', '독일 누적 확진자 수']].dropna()
subdf = subdf.rename(columns={'ds':'ds', '독일 누적 확진자 수':'y'})

m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(subdf);

future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)

m.plot(forecast);

# %%
m.plot_components(forecast)

# %% [markdown]
# - 5개 국가 모두 trend는 시간이 지날수록 계속해서 증가하는 추세이며, 90일 후에도 마찬가지로 예측되어진다.
#
# - 각 국가들의 일별 주기를 보았을 때 모두 한 주의 시작인 월요일, 화요일에 누적 확진자 수가 가장 적으며 주말의 시작인 금요일, 토요일에 누적 확진자 수가 많았다.
#
# - 각 국가들의 월별 주기를 보았을 때는 독일을 제외한 4개의 국가 모두 여름인 7월에 누적 확진자 수가 적은 편이며, 독일만 10~11월에 가장 적었다.

# %% [markdown]
# ---

# %% [markdown]
# # 문제 (6)
#
# - 여러분들이 선정한 5개 국가를 기준으로 우리나라는 어떻다고 이야기 할 수 있을까요
#
# - 그 판단의 근거를 다시 잘 정리해서 함께 보여주세요.
#
# - 이 과정에서 문제1에서 구하지 않은 또 다른 추가 데이터를 사용해도 됩니다.(예를 들어 백신 접종률 데이터)
#
# - 물론 추가되는 데이터는 여러분들이 직접 검색해서 찾아야 합니다.

# %% [markdown]
# ### 앞선 결과들의 정리해보자면...

# %% [markdown]
# - 문제(3)에서 우리나라의 방역 대응 능력을 평가할 수 있는 지표로 일일 사망자 수 대비 확진자 수 비율의 평균을 구했는데, 선정한 국가들 대비 우리나라의 평균 비율이 가장 낮았다.
#
# - 또한 문제(4)에서 구한 국가별 인구 대비 코로나 누적 확진자 비율, 국가별 인구 대비 코로나 누적 사망자 비율값 역시나 우리나라가 선정한 국가들에 비해 가장 낮았다.
#
# - 선정한 국가들인 일본, 미국, 영국, 독일 모두 G20국가에 해당하는 선진국들인데, 그들보다 코로나 사태의 현황이 양호한 편이라고 판단할 수 있다.
#
# - 또한 문제(3)에서 구한 방역 대응 능력 지표를 빗대었을때 방역 대응 능력도 선정된 국가들보다 훌륭하다고 판단되어진다.

# %% [markdown]
# #### 우리나라의 방역이 선정된 G20국가들에 비해 훌륭하다는 정확한 근거를 추가적으로 보여주기 위해 백신 접종률 데이터를 구해보았다

# %% [markdown]
# - https://ko.tradingeconomics.com/country-list/coronavirus-vaccination-rate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
from fbprophet import Prophet

# %matplotlib inline

# %%
url = 'https://ko.tradingeconomics.com/country-list/coronavirus-vaccination-rate'
driver = webdriver.Chrome('../driver/chromedriver.exe')
driver.get(url)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
table = soup.find('table', 'table table-hover')
table
# Out:
# <table class="table table-hover" data-sortable="">
# <thead>
# <tr>
# <th style="cursor: pointer">국가</th>
# <th data-sortable="true" style="cursor: pointer">마지막 </th>
# <th data-sortable="true" style="cursor: pointer">이전 </th>
# <th class="hidden-xs">참고</th>
# <th class="hidden-sm hidden-xs" data-sortable="false"> 단위</th>
# </tr>
# </thead>
# <tbody><tr class="datatable-row">
# <td style="max-width: 120px; overflow: hidden; padding-left: 10px; text-align: left; font-weight: 600;">
# <a href="/united-arab-emirates/coronavirus-vaccination-rate">
#                                         아랍 에미리트
#                                     </a></td>
# <td data-value="206.06">
#                                     206
#                                 </td>
# <td>206</td>
# <td class="hidden-xs"><span>2021-10</span></td>
# <td class="hidden-sm hidden-xs">
#                                     doses per 100 people
#                                 </td>
# </tr>
# ...

# %%
driver.quit()

# %%
df = pd.read_html(str(table))
vaccineRate = df[0]
vaccineRate.head()
# Out:
#         국가    마지막     이전       참고                    단위
# 0  아랍 에미리트  206.0  206.0  2021-10  doses per 100 people
# 1     이스라엘  179.0  179.0  2021-10  doses per 100 people
# 2       칠레  176.0  176.0  2021-10  doses per 100 people
# 3     싱가포르  166.0  166.0  2021-10  doses per 100 people
# 4   케이맨 제도  165.0  165.0  2021-10  doses per 100 people

# %%
vaccineRate.tail()
# Out:
#           국가   마지막    이전       참고                    단위
# 152   시에라 리온  4.41  4.41  2021-10  doses per 100 people
# 153    나이지리아  3.54  3.54  2021-10  doses per 100 people
# 154       수단  3.34  3.34  2021-10  doses per 100 people
# 155  파푸아 뉴기니  2.14  2.14  2021-10  doses per 100 people
# 156       말리  1.98  1.98  2021-10  doses per 100 people

# %%
# 컬럼간 계산을 위해 단위컬럼의 데이터 값 변경
vaccineRate.loc[vaccineRate['단위'] == 'doses per 100 people', '단위'] = 100

# %%
vaccineRate.head()
# Out:
#         국가    마지막     이전       참고   단위
# 0  아랍 에미리트  206.0  206.0  2021-10  100
# 1     이스라엘  179.0  179.0  2021-10  100
# 2       칠레  176.0  176.0  2021-10  100
# 3     싱가포르  166.0  166.0  2021-10  100
# 4   케이맨 제도  165.0  165.0  2021-10  100

# %%
# 마지막과 이전의 데이터가 동일하여 컬럼 하나 삭제
del vaccineRate['이전']

# %%
vaccineRate.head()
# Out:
#         국가    마지막       참고   단위
# 0  아랍 에미리트  206.0  2021-10  100
# 1     이스라엘  179.0  2021-10  100
# 2       칠레  176.0  2021-10  100
# 3     싱가포르  166.0  2021-10  100
# 4   케이맨 제도  165.0  2021-10  100

# %%
vaccineRate.columns = ['국가', '접종회분', '기준날짜', '단위(명)']

# %%
vaccineRate.head()
# Out:
#         국가   접종회분     기준날짜 단위(명)
# 0  아랍 에미리트  206.0  2021-10   100
# 1     이스라엘  179.0  2021-10   100
# 2       칠레  176.0  2021-10   100
# 3     싱가포르  166.0  2021-10   100
# 4   케이맨 제도  165.0  2021-10   100

# %%
# 필요한 국가들만 따로 dataframe 생성
vac_kor = vaccineRate.loc[vaccineRate['국가'] == '대한민국',]
vac_jap = vaccineRate.loc[vaccineRate['국가'] == '일본',]
vac_us = vaccineRate.loc[vaccineRate['국가'] == '미국',]
vac_uk = vaccineRate.loc[vaccineRate['국가'] == '연합 왕국',]
vac_ger = vaccineRate.loc[vaccineRate['국가'] == '독일',]

vac_5coun = pd.concat([vac_kor, vac_jap, vac_us, vac_uk, vac_ger], axis=0)
vac_5coun
# Out:
#        국가   접종회분     기준날짜 단위(명)
# 28   대한민국  138.0  2021-10   100
# 22     일본  141.0  2021-10   100
# 51     미국  121.0  2021-10   100
# 26  연합 왕국  139.0  2021-10   100
# 35     독일  131.0  2021-10   100

# %%
# 연합 왕국 -> 영국
vac_5coun.loc[vac_5coun['국가'] == '연합 왕국', '국가'] = '영국'

# %%
vac_5coun.set_index('국가',inplace=True)

# %%
vac_5coun = vac_5coun[['기준날짜', '접종회분', '단위(명)']]
vac_5coun.head()
# Out:
#          기준날짜   접종회분 단위(명)
# 국가
# 대한민국  2021-10  138.0   100
# 일본    2021-10  141.0   100
# 미국    2021-10  121.0   100
# 영국    2021-10  139.0   100
# 독일    2021-10  131.0   100

# %%
# 인당 접종회분 컬럼 추가
vac_5coun['인당 접종회분'] = vac_5coun['접종회분'] / vac_5coun['단위(명)']
vac_5coun
# Out:
#          기준날짜   접종회분 단위(명) 인당 접종회분
# 국가
# 대한민국  2021-10  138.0   100    1.38
# 일본    2021-10  141.0   100    1.41
# 미국    2021-10  121.0   100    1.21
# 영국    2021-10  139.0   100    1.39
# 독일    2021-10  131.0   100    1.31

# %% [markdown]
# #### 일단 현재까지 세계적으로 부스트샷의 기준이 2차 접종까지였으므로,
#    - 인당 접종회분을 2회분으로 나누면
#    - 부스트샷 기준 국가별 백신접종완료율을 확인할 수 있다.

# %%
vac_5coun['백신접종완료율(%)'] = vac_5coun['인당 접종회분'] / 2 * 100
vac_5coun
# Out:
#          기준날짜   접종회분 단위(명) 인당 접종회분 백신접종완료율(%)
# 국가
# 대한민국  2021-10  138.0   100    1.38       69.0
# 일본    2021-10  141.0   100    1.41       70.5
# 미국    2021-10  121.0   100    1.21       60.5
# 영국    2021-10  139.0   100    1.39       69.5
# 독일    2021-10  131.0   100    1.31       65.5

# %%
# 5개 국가 백신접종완료율 시각화
vac_5coun['백신접종완료율(%)'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 코로나 백신접종완료 비율(부스트샷 2회 기준)(%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange']
)

# %% [markdown]
# - 백신접종완료비율로만 보았을 때는 일본이 70.5% 가장 높았다.
# - 대한민국은 확진자비율, 사망자비율, 방역대응능력지표로 보았을 때는 가장 적었지만, 백신접종완료비율로는 5개의 국가들 중 3위에 있었다.
# - 하지만 1등 백신접종완료 국가인 일본과 비교했을때 1.5% 정도밖에 차이가 나지 않기 때문에 백신접종 현황면에서도 뛰어나다고 볼 수 있다.

# %%
# 인구 컬럼 추가
vac_5coun['인구수'] = [51611400, 125960000, 332915074, 67886011, 83783942 ]
vac_5coun
# Out:
#          기준날짜   접종회분 단위(명) 인당 접종회분 백신접종완료율(%)        인구수
# 국가
# 대한민국  2021-10  138.0   100    1.38       69.0   51611400
# 일본    2021-10  141.0   100    1.41       70.5  125960000
# 미국    2021-10  121.0   100    1.21       60.5  332915074
# 영국    2021-10  139.0   100    1.39       69.5   67886011
# 독일    2021-10  131.0   100    1.31       65.5   83783942

# %%
# 국가별 총 접종회분 현황 시각화
vac_5coun['총 접종회분'] = vac_5coun['인당 접종회분'] * vac_5coun['인구수']
vac_5coun.sort_values(by='총 접종회분', ascending=False)
# Out:
#          기준날짜   접종회분 단위(명) 인당 접종회분 백신접종완료율(%)        인구수        총 접종회분
# 국가
# 미국    2021-10  121.0   100    1.21       60.5  332915074  402827239.54
# 일본    2021-10  141.0   100    1.41       70.5  125960000   177603600.0
# 독일    2021-10  131.0   100    1.31       65.5   83783942  109756964.02
# 영국    2021-10  139.0   100    1.39       69.5   67886011   94361555.29
# 대한민국  2021-10  138.0   100    1.38       69.0   51611400    71223732.0

# %% [markdown]
# - 추가적으로, 총 접종회분은 미국, 일본, 독일, 영국, 대한민국 순으로 많았다

# %% [markdown]
# ---

# %% [markdown]
# # 문제 (7)
#
# - 이제 다시 문제6에 이어서 혹시 한 나라의 의료 수준을 가늠할 데이터가 있을까요? 예를 들어 심혈관계 혹은 암으로 인한 사망률 혹은 생존률과 같은 데이터
# - 매우 조심스럽지만 한 나라의 의료 수준을 수치화 할 수 있을까요?
# - 그렇다면 그의 의료 수준 대비 covid19 데이터를 다시 정리해 볼 수 있을까요?
# - 그렇게 했을때 문제6의 결과와 비교해서 달라져 보이는 것이 있나요?
# - 이번 문제는 추가로 인구대비의 상황도 함께 고려해주세요.

# %% [markdown]
# #### 다른 질병들의 국가별 사망률, 생존율 데이터를 통해 국가별 의료 수준을 확인하고, 국가별 코로나 사망률 데이터와 비교해보자

# %% [markdown]
# - 'https://en.wikipedia.org/wiki/List_of_countries_by_quality_of_healthcare'

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_quality_of_healthcare'
driver = webdriver.Chrome('../driver/chromedriver.exe')
driver.get(url)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# 대장암 5년 생존율
table1 = soup.select_one('#mw-content-text > div.mw-parser-output > div:nth-child(10) > table > tbody > tr > td > table')

# 유방암 5년 생존율
table2 = soup.select_one('#mw-content-text > div.mw-parser-output > div:nth-child(12) > table > tbody > tr > td:nth-child(1) > table')

# 자궁경부암 5년 생존율
table3 = soup.select_one('#mw-content-text > div.mw-parser-output > div:nth-child(12) > table > tbody > tr > td:nth-child(2) > table')

# 심장마비 퇴원 100명당 30일 입원 사망률
table4 = soup.select_one('#mw-content-text > div.mw-parser-output > div:nth-child(14) > table > tbody > tr > td:nth-child(1)')

# 출혈성 뇌졸중 퇴원 100명당 30일 입원 사망률
table5 = soup.select_one('#mw-content-text > div.mw-parser-output > div:nth-child(14) > table > tbody > tr > td:nth-child(2)')

# 허혈성 뇌졸중 퇴원 100명당 30일 입원 사망률 
table6 = soup.select_one('#mw-content-text > div.mw-parser-output > div:nth-child(14) > table > tbody > tr > td:nth-child(3)')

# %%
driver.quit()

# %%
# 5개 국가 list
country = ['South Korea', 'Japan', 'United States', 'United Kingdom', 'Germany' ]

# %%
# 대장암 5년 생존율
df_1 = pd.read_html(str(table1))
df_1 = df_1[0]
df_1 = df_1.rename(columns={'Country': '국가'})
df_1.set_index('국가', inplace=True)
del df_1['Rank']
df_1 = df_1.loc[country,:].sort_values(by='Survivalrate', ascending=False)
df_1 = df_1.rename(
    columns={'Survivalrate': '대장암 생존율', 'Period': '기간'},
    index={'South Korea': '대한민국', 'Japan': '일본', 'United States': '미국', 'United Kingdom': '영국', 'Germany': '독일'}
)

# 시각화를 위해 생존율 data type 변경
df_1.loc[df_1['대장암 생존율'] == '72.8%', '대장암 생존율'] = 72.8
df_1.loc[df_1['대장암 생존율'] == '68.0%', '대장암 생존율'] = 68
df_1.loc[df_1['대장암 생존율'] == '64.7%', '대장암 생존율'] = 64.7
df_1.loc[df_1['대장암 생존율'] == '64.3%', '대장암 생존율'] = 64.3
df_1.loc[df_1['대장암 생존율'] == '54.5%', '대장암 생존율'] = 54.5
df_1['대장암 생존율'] = df_1['대장암 생존율'].astype('float')
df_1
# Out:
#       대장암 생존율         기간
# 국가
# 대한민국     72.8  2006–2011
# 일본       68.0  2000–2005
# 미국       64.7  2004–2009
# 독일       64.3  2004–2009
# 영국       54.5  2007–2012

# %%
# 국가별 대장암 5년 생존율 시각화
df_1['대장암 생존율'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 대장암 5년 생존율(%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange']
)

# %% [markdown]
# - 국가별 대장암 5년 생존율은 대한민국, 일본, 미국, 독일, 영국 순으로 높았다.
# - 이것을 미루어 보았을 때 우리나라의 대장암관련 의료기술은 수준이 높다고 볼 수 있다.

# %%
# 유방암 5년 생존율
df_2 = pd.read_html(str(table2))
df_2 = df_2[0]
df_2 = df_2.rename(columns={'Country': '국가'})
df_2.set_index('국가', inplace=True)
del df_2['Rank']
df_2 = df_2.loc[country,:].sort_values(by='Survivalrate', ascending=False)
df_2 = df_2.rename(
    columns={'Survivalrate': '유방암 생존율', 'Period': '기간'},
    index={'South Korea': '대한민국', 'Japan': '일본', 'United States': '미국', 'United Kingdom': '영국', 'Germany': '독일'}
)

# 시각화를 위해 생존율 data type 변경
df_2.loc[df_2['유방암 생존율'] == '88.7%', '유방암 생존율'] = 88.7
df_2.loc[df_2['유방암 생존율'] == '87.3%', '유방암 생존율'] = 87.3
df_2.loc[df_2['유방암 생존율'] == '85.2%', '유방암 생존율'] = 85.2
df_2.loc[df_2['유방암 생존율'] == '85.0%', '유방암 생존율'] = 85.0
df_2.loc[df_2['유방암 생존율'] == '82.0%', '유방암 생존율'] = 82.0
df_2['유방암 생존율'] = df_2['유방암 생존율'].astype('float')
df_2
# Out:
#       유방암 생존율         기간
# 국가
# 미국       88.7  2004–2009
# 일본       87.3  2000–2005
# 대한민국     85.2  2006–2011
# 독일       85.0  2004–2009
# 영국       82.0  2007–2012

# %%
# 국가별 유방암 5년 생존율 시각화
df_2['유방암 생존율'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 유방암 5년 생존율(%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange']
)

# %% [markdown]
# - 국가별 유방암 5년 생존율은 미국, 일본, 대한민국, 독일, 영국 순으로 높았다.
# - 우리나라가 비록 비교 국가들대비 3위에 해당하지만 앞선 대장암 생존율의 국가 간 편차 대비 유방암 생존율의 국가 간 편차가 적은 수치이며,
# - 1위 국가인 미국과 3.5%밖에 차이가 나지 않는 것을 미루어 보았을 때 유방암관련 의료수준도 뛰어나다고 볼 수 있다.

# %%
# 자궁경부암 5년 생존율
df_3 = pd.read_html(str(table3))
df_3 = df_3[0]
df_3 = df_3.rename(columns={'Country': '국가'})
df_3.set_index('국가', inplace=True)
del df_3['Rank']
df_3 = df_3.loc[country,:].sort_values(by='Survivalrate', ascending=False)
df_3 = df_3.rename(
    columns={'Survivalrate': '자궁경부암 생존율', 'Period': '기간'},
    index={'South Korea': '대한민국', 'Japan': '일본', 'United States': '미국', 'United Kingdom': '영국', 'Germany': '독일'}
)

# 시각화를 위해 생존율 data type 변경
df_3.loc[df_3['자궁경부암 생존율'] == '76.8%', '자궁경부암 생존율'] = 76.8
df_3.loc[df_3['자궁경부암 생존율'] == '70.2%', '자궁경부암 생존율'] = 70.2
df_3.loc[df_3['자궁경부암 생존율'] == '64.5%', '자궁경부암 생존율'] = 64.5
df_3.loc[df_3['자궁경부암 생존율'] == '62.2%', '자궁경부암 생존율'] = 62.2
df_3.loc[df_3['자궁경부암 생존율'] == '60.9%', '자궁경부암 생존율'] = 60.9
df_3['자궁경부암 생존율'] = df_3['자궁경부암 생존율'].astype('float')
df_3
# Out:
#       자궁경부암 생존율         기간
# 국가
# 대한민국       76.8  2006–2011
# 일본         70.2  2000–2005
# 독일         64.5  2004–2009
# 미국         62.2  2004–2009
# 영국         60.9  2007–2012

# %%
# 국가별 자궁경부암 5년 생존율 시각화
df_3['자궁경부암 생존율'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 자궁경부암 5년 생존율(%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange']
)

# %% [markdown]
# - 국가별 자궁경부암의 5년 생존율은 대한민국, 일본, 독일, 미국, 영국 순으로 높았다.
# - 국가별 자궁경부암에서도 가장 높은 생존율을 보았을 때, 우리나라의 자궁경부암관련 의료기술도 뛰어나다고 볼 수 있다.

# %%
# 심장마비 퇴원 100명당 30일 입원 사망률
df_4 = pd.read_html(str(table4))
df_4 = df_4[0]
df_4 = df_4.rename(columns={'Country': '국가'})
df_4.set_index('국가', inplace=True)
del df_4['Rank']
df_4 = df_4.loc[country,:].sort_values(by='Deathrate', ascending=False)
df_4 = df_4.rename(
    columns={'Deathrate': '심장마비 사망률', 'Period': '기간'},
    index={'South Korea': '대한민국', 'Japan': '일본', 'United States': '미국', 'United Kingdom': '영국', 'Germany': '독일'}
)

df_4
# Out:
#       심장마비 사망률    기간
# 국가
# 일본        12.2  2011
# 대한민국       8.9  2011
# 독일         8.9  2011
# 영국         7.8  2011
# 미국         5.5  2010

# %%
# 국가별 심장마비 퇴원 100명당 30일 입원 사망률 시각화
df_4['심장마비 사망률'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 심장마비 퇴원 100명당 30일 입원 사망률(%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange']
)

# %% [markdown]
# - 국가별 심장마비 퇴원 100명당 30일 입원 사망률은 일본, 독일, 대한민국, 영국, 미국 순으로 높았다.
# - 우리나라는 해당 국가대비 3위로 약 8.9%에 이르렀다.

# %%
# 출혈성 뇌졸중 퇴원 100명당 30일 입원 사망률
df_5 = pd.read_html(str(table5))
df_5 = df_5[0]
df_5 = df_5.rename(columns={'Country': '국가'})
df_5.set_index('국가', inplace=True)
del df_5['Rank']
df_5 = df_5.loc[country,:].sort_values(by='Deathrate', ascending=False)
df_5 = df_5.rename(
    columns={'Deathrate': '출혈성 뇌졸중 사망률', 'Period': '기간'},
    index={'South Korea': '대한민국', 'Japan': '일본', 'United States': '미국', 'United Kingdom': '영국', 'Germany': '독일'}
)

df_5
# Out:
#       출혈성 뇌졸중 사망률    기간
# 국가
# 영국           29.6  2011
# 미국           22.3  2010
# 독일           17.5  2011
# 대한민국         13.1  2011
# 일본           11.8  2011

# %%
# 국가별 출혈성 뇌졸중 퇴원 100명당 30일 입원 사망률 시각화
df_5['출혈성 뇌졸중 사망률'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 출혈성 뇌졸중 퇴원 100명당 30일 입원 사망률(%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange']
)

# %% [markdown]
# - 국가별 출혈성 뇌졸중 퇴원 100명당 30일 입원 사망률은 영국, 미국, 독일, 대한민국, 일본 순으로 높았다.
# - 우리나라는 해당 국가대비 2위로 약 13.1%에 이르렀다.

# %%
# 허혈성 뇌졸중 퇴원 100명당 30일 입원 사망률 
df_6 = pd.read_html(str(table6))
df_6 = df_6[0]
df_6 = df_6.rename(columns={'Country': '국가'})
df_6.set_index('국가', inplace=True)
del df_6['Rank']
df_6 = df_6.loc[country,:].sort_values(by='Deathrate', ascending=False)
df_6 = df_6.rename(
    columns={'Deathrate': '허혈성 뇌졸중 사망률', 'Period': '기간'},
    index={'South Korea': '대한민국', 'Japan': '일본', 'United States': '미국', 'United Kingdom': '영국', 'Germany': '독일'}
)

df_6
# Out:
#       허혈성 뇌졸중 사망률    기간
# 국가
# 영국           10.4  2011
# 독일            6.7  2011
# 미국            4.3  2010
# 대한민국          3.4  2011
# 일본            3.0  2011

# %%
# 국가별 허혈성 뇌졸중 퇴원 100명당 30일 입원 사망률 시각화
df_6['허혈성 뇌졸중 사망률'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 허혈성 뇌졸중 퇴원 100명당 30일 입원 사망률(%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange']
)

# %% [markdown]
# - 국가별 허혈성 뇌졸중 퇴원 100명당 30일 입원 사망률은 일본, 독일, 대한민국, 영국, 미국 순으로 높았다.
# - 우리나라는 해당 국가대비 2위로 약 3.4%에 이르렀다.

# %% [markdown]
# #### 문제(4)에서 구한 코로나 데이터를 다시 가져와서 전체적으로 비교해보자.
#    - 현재 우리는 대장암, 유방암 자궁경부암 생존율과 심장마비, 출혈성 뇌졸중, 허혈성 뇌졸중에 대한 사망률을 확인할 수 있었다.
#    - 따라서 위에서 구한 코로나 사망자 비율을 통해 생존율을 구하여 6개의 질병의 생존율과 비교해보기로 하였다.

# %%
# 데이터 병합을 위해 인덱스 재설정
confirmed_pop_rate.reset_index(inplace=True)
confirmed_pop_rate.rename(columns={'Country/Region': '국가'}, inplace=True)
confirmed_pop_rate.loc[confirmed_pop_rate['국가'] == '한국', '국가'] = '대한민국'
confirmed_pop_rate.set_index('국가', inplace=True)
confirmed_pop_rate
# Out:
#      현재 누적 확진자 수 현재 누적 사망자 수        인구수 인구 대비 누적 확진자 비율 인구 대비 누적 사망자 비율
# 국가
# 대한민국      340978        2644   51611400        0.660664        0.005123
# 일본       1714201       18084  125960000        1.360909        0.014357
# 미국      44884868      723754  332915074       13.482378        0.217399
# 영국       8361651      138379   67886011       12.317193         0.20384
# 독일       4366833       94605   83783942        5.212017        0.112915

# %%
# 인구 대비 누적 생존율 컬럼 생성
confirmed_pop_rate['인구 대비 코로나 생존율'] = 100 - confirmed_pop_rate['인구 대비 누적 사망자 비율']
confirmed_pop_rate
# Out:
#      현재 누적 확진자 수 현재 누적 사망자 수        인구수 인구 대비 누적 확진자 비율 인구 대비 누적 사망자 비율  \
# 국가
# 대한민국      340978        2644   51611400        0.660664        0.005123
# 일본       1714201       18084  125960000        1.360909        0.014357
# 미국      44884868      723754  332915074       13.482378        0.217399
# 영국       8361651      138379   67886011       12.317193         0.20384
# 독일       4366833       94605   83783942        5.212017        0.112915
#
#      인구 대비 코로나 생존율
# 국가
# 대한민국     99.994877
# 일본       99.985643
# 미국       99.782601
# 영국        99.79616
# 독일       99.887085

# %%
# 심장마비, 출혈성 뇌졸중, 허혈성 뇌졸중 생존율 컬럼 추가
df_4['심장마비 생존율'] = 100 - df_4['심장마비 사망률']
df_5['출혈성 뇌졸중 생존율'] = 100 - df_5['출혈성 뇌졸중 사망률']
df_6['허혈성 뇌졸중 생존율'] = 100 - df_6['허혈성 뇌졸중 사망률']

# %%
# 6개 질병의 생존율 데이터 프레임 병합
df_disease = pd.concat([df_1['대장암 생존율'], 
                        df_2['유방암 생존율'], 
                        df_3['자궁경부암 생존율'],
                        df_4['심장마비 생존율'],
                        df_5['출혈성 뇌졸중 생존율'],
                        df_6['허혈성 뇌졸중 생존율']], axis=1)

df_disease
# Out:
#       대장암 생존율  유방암 생존율  자궁경부암 생존율  심장마비 생존율  출혈성 뇌졸중 생존율  허혈성 뇌졸중 생존율
# 국가
# 대한민국     72.8     85.2       76.8      91.1         86.9         96.6
# 일본       68.0     87.3       70.2      87.8         88.2         97.0
# 미국       64.7     88.7       62.2      94.5         77.7         95.7
# 독일       64.3     85.0       64.5      91.1         82.5         93.3
# 영국       54.5     82.0       60.9      92.2         70.4         89.6

# %% [markdown]
# #### 6개 질병에 대한 평균 생존율을 나라별로 구해보자

# %%
# 6개 질병의 생존율과 평균 생존율 데이터 프레임 생성
df_disease['평균 질병 생존율'] = round(np.mean(df_disease, axis=1), 1)
df_disease
# Out:
#       대장암 생존율  유방암 생존율  자궁경부암 생존율  심장마비 생존율  출혈성 뇌졸중 생존율  허혈성 뇌졸중 생존율  \
# 국가
# 대한민국     72.8     85.2       76.8      91.1         86.9         96.6
# 일본       68.0     87.3       70.2      87.8         88.2         97.0
# 미국       64.7     88.7       62.2      94.5         77.7         95.7
# 독일       64.3     85.0       64.5      91.1         82.5         93.3
# 영국       54.5     82.0       60.9      92.2         70.4         89.6
#
#       평균 질병 생존율
# 국가
# 대한민국       84.9
# 일본         83.1
# 미국         80.6
# 독일         80.1
# 영국         74.9

# %%
# 6개 질병의 평균 생존율 시각화
df_disease['평균 질병 생존율'].sort_values().plot(
    kind='barh', 
    figsize=(10, 10),
    title='국가별 6개 질병에 대한 평균 생존율(%)',
    xlabel='국가',
    color=['red', 'blue', 'green', 'purple', 'orange']
)

# %% [markdown]
# - 선정된 g20 4개 국가 대비 대한민국의 6개 질병에 대한 생존율이 84.9%로 가장 높았다.
# - 위의 통계로 보아 대한민국의 의료 기술 수준이 세계적으로 뛰어난 수준이라고 판단된다.

# %% [markdown]
# #### 평균 질병 생존율과 코로나 생존율 비교 및 백신 접종 완료율과 코로나 생존율 비교

# %%
# 코로나 생존율과 데이터 프레임 병합
df_disease = pd.concat([df_disease, confirmed_pop_rate['인구 대비 코로나 생존율']], axis=1)
df_disease
# Out:
#       대장암 생존율  유방암 생존율  자궁경부암 생존율  심장마비 생존율  출혈성 뇌졸중 생존율  허혈성 뇌졸중 생존율  \
# 국가
# 대한민국     72.8     85.2       76.8      91.1         86.9         96.6
# 일본       68.0     87.3       70.2      87.8         88.2         97.0
# 미국       64.7     88.7       62.2      94.5         77.7         95.7
# 독일       64.3     85.0       64.5      91.1         82.5         93.3
# 영국       54.5     82.0       60.9      92.2         70.4         89.6
#
#       평균 질병 생존율 인구 대비 코로나 생존율
# 국가
# 대한민국       84.9     99.994877
# 일본         83.1     99.985643
# 미국         80.6     99.782601
# 독일         80.1     99.887085
# 영국         74.9      99.79616

# %%
# 백신 접종완료율 컬럼 추가
df_disease['백신접종완료율'] = vac_5coun['백신접종완료율(%)']
df_disease
# Out:
#       대장암 생존율  유방암 생존율  자궁경부암 생존율  심장마비 생존율  출혈성 뇌졸중 생존율  허혈성 뇌졸중 생존율  \
# 국가
# 대한민국     72.8     85.2       76.8      91.1         86.9         96.6
# 일본       68.0     87.3       70.2      87.8         88.2         97.0
# 미국       64.7     88.7       62.2      94.5         77.7         95.7
# 독일       64.3     85.0       64.5      91.1         82.5         93.3
# 영국       54.5     82.0       60.9      92.2         70.4         89.6
#
#       평균 질병 생존율 인구 대비 코로나 생존율 백신접종완료율
# 국가
# 대한민국       84.9     99.994877    69.0
# 일본         83.1     99.985643    70.5
# 미국         80.6     99.782601    60.5
# 독일         80.1     99.887085    65.5
# 영국         74.9      99.79616    69.5

# %%
# 국가별 평균 질병 생존율과 코로나 생존율 시각화
def drawGraph():
    plt.figure(figsize=(12, 10))
    plt.bar(df_disease.index, 
            df_disease['평균 질병 생존율'], 
            label='평균 질병 생존율(%)', 
            color='lightblue',
            edgecolor='black',
            linewidth=1.2
    )
    plt.plot(df_disease.index, 
             df_disease['인구 대비 코로나 생존율'], 
             label='코로나 생존율(%)', 
             linestyle='-',
             linewidth=1.2,
             color='black',
             marker='o',
             markersize=10,
             markerfacecolor='yellow',
             markeredgecolor='black'
    )
    plt.title('국가별 평균 질병 생존율 및 코로나 생존율', size=25)
    plt.xlabel("국가", size=20)
    plt.ylabel("생존율(%)", size=20)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.grid()
    plt.legend(loc='best')
    plt.show()

# %%
drawGraph()

# %%
# 코로나 생존율과 백신 접종 완료율 시각화
def drawGraph2():
    plt.figure(figsize=(12, 10))
    plt.bar(df_disease.index, 
            df_disease['백신접종완료율'], 
            label='백신 접종 완료율(%)', 
            color='orange',
            edgecolor='black',
            linewidth=1.2
    )
    plt.plot(df_disease.index, 
             df_disease['인구 대비 코로나 생존율'], 
             label='코로나 생존율(%)', 
             linestyle='-',
             linewidth=1.2,
             color='black',
             marker='o',
             markersize=10,
             markerfacecolor='yellow',
             markeredgecolor='black'
    )
    plt.title('국가별 백신 접종 완료율 및 코로나 생존율', size=25)
    plt.xlabel("국가", size=20)
    plt.ylabel("비율(%)", size=20)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.grid()
    plt.legend(loc='best')
    plt.show()

# %%
drawGraph2()

# %% [markdown]
# ### 결과적으로,
#    - 6개의 대표적인 질병에 대한 생존율은 대한민국, 일본, 미국, 독일, 영국 순으로 높았다.
#    - 대한민국과 일본의 질병에 대한 생존율이 높은 것을 미루어보아 의료 기술 수준이 높다고 판단된다.
#    - 코로나 생존율은 대한민국, 일본, 독일, 영국, 미국 순으로 높았으나 대체적으로 비슷한 수치이다.
#    - 코로나 백신 접종 완료율로만 보았을 때는 일본, 영국, 대한민국, 독일, 미국 순으로 높았다.
#    - 하지만 접종 완료율 대비 생존율을 보았을 때도 마찬가지로 코로나 생존율과 함께 국가별로 거의 비슷한 수치를 보였다.
#    - 따라서 코로나에 대응하는 5개의 OECD 국가들은 미세한 차이가 있지만 모두 적절하게 방역 정책을 펼치고 있다고 판단된다.  .
#    - 또한 코로나는 비교되는 6개의 질병에 비해 치사율은 높지 않다고 볼 수 있다.
